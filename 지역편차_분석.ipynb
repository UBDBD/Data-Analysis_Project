# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import json
import requests
import geopandas as gpd
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 배경

# %% [markdown]
# ## 인구이동

# %%
path_1 ='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/move.xlsx'

df_1 = pd.read_excel(path_1)
df_1
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        시점 행정구역(시군구)별  총전입 (명)  총전출 (명)  순이동 (명)  시도간전입 (명)  시도간전출 (명)
# 0    2014      서울특별시  1573594  1661425   -87831     475571     563402
# 1    2014      부산광역시   485710   500802   -15092     132428     147520
# 2    2014      대구광역시   350213   365739   -15526      97571     113097
# 3    2014      인천광역시   452297   442973     9324     156922     147598
# 4    2014      광주광역시   243066   246043    -2977      78745      81722
# ..    ...        ...      ...      ...      ...        ...        ...
# 165  2023       전라북도   188788   193245    -4457      53965      58422
# 166  2023       전라남도   183557   185357    -1800      71675      73475
# 167  2023       경상북도   254287   262492    -8205     107068     115273
# 168  2023       경상남도   300309   316609   -16300     103910     120210
# 169  2023    제주특별자치도    81508    83195    -1687      30770      32457
#
# [170 rows x 7 columns]

# %%
df_1.rename(columns={'행정구역(시군구)별':'도시',
                   '순이동 (명)': '순이동'}, inplace=True)
df_1['지역']='비수도권'
df_1.loc[df_1['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'
df_1=df_1[['시점','지역', '도시','순이동']]
df_1
# Out:
#        시점    지역       도시    순이동
# 0    2014   수도권    서울특별시 -87831
# 1    2014  비수도권    부산광역시 -15092
# 2    2014  비수도권    대구광역시 -15526
# 3    2014   수도권    인천광역시   9324
# 4    2014  비수도권    광주광역시  -2977
# ..    ...   ...      ...    ...
# 165  2023  비수도권     전라북도  -4457
# 166  2023  비수도권     전라남도  -1800
# 167  2023  비수도권     경상북도  -8205
# 168  2023  비수도권     경상남도 -16300
# 169  2023  비수도권  제주특별자치도  -1687
#
# [170 rows x 4 columns]

# %%
df_1_group = df_1.groupby(['지역','시점'])['순이동'].sum().reset_index()
df_1_group
# Out:
#       지역    시점    순이동
# 0   비수도권  2014  21111
# 1   비수도권  2015  32950
# 2   비수도권  2016    863
# 3   비수도권  2017 -16006
# 4   비수도권  2018 -59797
# 5   비수도권  2019 -82741
# 6   비수도권  2020 -87775
# 7   비수도권  2021 -55697
# 8   비수도권  2022 -36643
# 9   비수도권  2023 -46869
# 10   수도권  2014 -21111
# 11   수도권  2015 -32950
# 12   수도권  2016   -863
# 13   수도권  2017  16006
# 14   수도권  2018  59797
# 15   수도권  2019  82741
# 16   수도권  2020  87775
# 17   수도권  2021  55697
# 18   수도권  2022  36643
# 19   수도권  2023  46869

# %%
df_1_pivot = df_1_group.pivot_table(values='순이동', index='시점', columns='지역')
df_1_pivot_sum = df_1_pivot.cumsum()

# %%
# 연도별 수도권 인구이동
fig = go.Figure()

fig.add_trace(go.Bar(
    x=df_1_group['시점'],
    y=df_1_group[df_1_group['지역']=='수도권']['순이동'],
    name='인구이동',
    marker_color='rgb(150,150,450)',
    text=round(df_1_group[df_1_group['지역']=='수도권']['순이동']/1000, 1)
))
fig.add_trace(go.Scatter(
    x=df_1_group['시점'],
    y=df_1_group[df_1_group['지역']=='수도권']['순이동'],
    mode='lines+markers',
    name='인구이동',
    marker_color='rgb(100,100,300)'
))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bd4ac431-1666-400a-986d-a265b8d25b2a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd4ac431-1666-400a-986d-a265b8d25b2a")) {                    Plotly.newPlot(                        "bd4ac431-1666-400a-986d-a265b8d25b2a",                        [{"marker":{"color":"rgb(150,150,450)"},"name":"\uc778\uad6c\uc774\ub3d9","text":[-21.1,-33.0,-0.9,16.0,59.8,82.7,87.8,55.7,36.6,46.9],"x":[2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"y":[-21111,-32950,-863,16006,59797,82741,87775,55697,36643,46869],"type":"bar"},{"marker":{"color":"rgb(100,100,300)"},"mode":"lines+markers","name":"\uc778\uad6c\uc774\ub3d9","x":[2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"y":[-21111,-32950,-863,16006,59797,82741,87775,55697,36643,46869],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"}, ...

# %%
# 연도별 수도권 누적 인구이동
fig = go.Figure()

fig.add_trace(go.Bar(
    x=df_1_pivot_sum.index,
    y=df_1_pivot_sum['수도권'],
    name='누적 인구이동',
    marker_color='rgb(150,150,450)',
    text=round(df_1_pivot_sum['수도권']/1000,1)
))

fig.add_trace(go.Scatter(
    x=df_1_pivot_sum.index,
    y=df_1_pivot_sum['수도권'],
    mode='lines+markers',
    name='누적 인구이동',
    marker_color='rgb(100,100,300)'
))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee1f9c57-3b2a-4ac1-a12b-83bfc272a898" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee1f9c57-3b2a-4ac1-a12b-83bfc272a898")) {                    Plotly.newPlot(                        "ee1f9c57-3b2a-4ac1-a12b-83bfc272a898",                        [{"marker":{"color":"rgb(150,150,450)"},"name":"\ub204\uc801 \uc778\uad6c\uc774\ub3d9","text":[-21.1,-54.1,-54.9,-38.9,20.9,103.6,191.4,247.1,283.7,330.6],"x":[2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"y":[-21111,-54061,-54924,-38918,20879,103620,191395,247092,283735,330604],"type":"bar"},{"marker":{"color":"rgb(100,100,300)"},"mode":"lines+markers","name":"\ub204\uc801 \uc778\uad6c\uc774\ub3d9","x":[2014,2015,2016,2017,2018,2019,2020,2021,2022,2023],"y":[-21111,-54061,-54924,-38918,20879,103620,191395,247092,283735,330604],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"co ...

# %% [markdown]
# ## 인구분포

# %%
path_2='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/people.xlsx'

df_2 = pd.read_excel(path_2)
df_2.head()
# Out:
#        시점 행정구역(시군구)별 성별          계    0 - 4세    5 - 9세  10 - 14세  15 - 19세  \
# 0  2023.0      서울특별시  계  9334933.5  220265.5  308678.0  357808.5  381243.0
# 1  2023.0      부산광역시  계    3291326   78305.5  121997.0  133933.5  130393.0
# 2  2023.0      대구광역시  계    2372562   59547.0   94764.0  106649.0  109453.5
# 3  2023.0      인천광역시  계    2966979   84134.0  121382.0  137201.0  134775.0
# 4  2023.0      광주광역시  계    1420562   40702.5   62653.5   73565.0   75537.0
#
#    20 - 24세  25 - 29세  ...  65 - 69세  70 - 74세  75 - 79세    80세 이상  80 - 84세  \
# 0  564693.5  802843.5  ...  588956.0  409781.0  311120.5  372713.5  222881.5
# 1  177426.5  208199.5  ...  258134.5  184261.0  129523.0  154773.0   94504.0
# 2  137540.5  150989.0  ...  157212.0  113543.0   77986.0  106327.5   62908.5
# 3  163436.0  205728.5  ...  179728.5  110819.0   81399.0  106370.5   60135.5
# 4   93358.0  100970.0  ...   76434.0   55494.0   41910.0   54074.0   31736.5
#
#      85세 이상  85 - 89세  90 - 94세  95 - 99세  100세 이상
# 0  149832.0  105271.0   35320.5    7997.0   1243.5
# 1   60269.0   43269.5   13677.5    2927.5    394.5
# 2   43419.0   31388.5    9946.0    1837.5    247.0
# 3   46235.0   31607.0   11530.5    2665.5    432.0
# 4   22337.5   15645.5    5395.5    1114.0    182.5
#
# [5 rows x 27 columns]

# %%
df_2=df_2.drop(columns=['성별','시점'])

# %%
df_2=df_2.rename(columns={'행정구역(시군구)별':'도시'})

# %%
df_2['지역']='비수도권'
df_2.loc[df_2['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'

# %%
df_2.insert(1, '지역', df_2.pop('지역'))

# %%
url = 'https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/SIDO_MAP_2022.json'
response = requests.get(url)

if response.status_code == 200:
    geo_json = json.loads(response.text)  # 문자열 형태로 변환 후에 파싱합니다.
    # geo_json 이용한 작업 수행
else:
    print("데이터를 가져오는 데 실패했습니다:", response.status_code)

# %%
#with open('https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/SIDO_MAP_2022.json') as response:
 #   geo_json = json.load(response)

# %%
geo_df = gpd.GeoDataFrame.from_features(geo_json['features'])
geo_df.head()
# Out:
#                                             geometry CTPRVN_CD CTP_ENG_NM  \
# 0  POLYGON ((126.98400 37.63600, 126.94800 37.657...        11      Seoul
# 1  POLYGON ((129.28800 35.32100, 129.26300 35.386...        26      Busan
# 2  POLYGON ((128.47300 35.83300, 128.47000 35.806...        27      Daegu
# 3  MULTIPOLYGON (((126.34300 37.64400, 126.37500 ...        28    Incheon
# 4  POLYGON ((126.76000 35.25900, 126.73600 35.251...        29    Gwangju
#
#   CTP_KOR_NM
# 0      서울특별시
# 1      부산광역시
# 2      대구광역시
# 3      인천광역시
# 4      광주광역시

# %%
df_2.drop(17,inplace=True)

# %%
df_2['계'] = df_2['계'].astype(float)

# %%
df_2['비율'] = df_2['계']/df_2['계'].sum()

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   도시        17 non-null     object
#  1   지역        17 non-null     object
#  2   계         17 non-null     float64
#  3   0 - 4세    17 non-null     float64
#  4   5 - 9세    17 non-null     float64
#  5   10 - 14세  17 non-null     float64
#  6   15 - 19세  17 non-null     float64
#  7   20 - 24세  17 non-null     float64
#  8   25 - 29세  17 non-null     float64
#  9   30 - 34세  17 non-null     float64
#  10  35 - 39세  17 non-null     float64
#  11  40 - 44세  17 non-null     float64
#  12  45 - 49세  17 non-null     float64
#  13  50 - 54세  17 non-null     float64
#  14  55 - 59세  17 non-null     float64
#  15  60 - 64세  17 non-null     float64
#  16  65 - 69세  17 non-null     float64
#  17  70 - 74세  17 non-null     float64
#  18  75 - 79세  17 non-null     float64
#  19  80세 이상    17 non-null     float64
#  20  80 - 84세  17 non-null     float64
#  21  85세 이상    17 non-null     float64
#  22  85 - 89세  17 non-null     float64
#  23  90 - 94세  17 non-null     float64
#  24  95 - 99세  17 non-null     float64
#  25  100세 이상   17 non-null     float64
#  26  비율        17 non-null     float64
# dtypes: float64(25), object(2)
# memory usage: 3.7+ KB

# %%
df_2
# Out:
#          도시    지역           계    0 - 4세    5 - 9세  10 - 14세  15 - 19세  \
# 0     서울특별시   수도권   9334933.5  220265.5  308678.0  357808.5  381243.0
# 1     부산광역시  비수도권   3291326.0   78305.5  121997.0  133933.5  130393.0
# 2     대구광역시  비수도권   2372562.0   59547.0   94764.0  106649.0  109453.5
# 3     인천광역시   수도권   2966979.0   84134.0  121382.0  137201.0  134775.0
# 4     광주광역시  비수도권   1420562.0   40702.5   62653.5   73565.0   75537.0
# 5     대전광역시  비수도권   1438846.0   40665.0   58776.0   67868.5   71044.0
# 6     울산광역시  비수도권   1103825.0   31542.0   50497.0   56355.0   53417.5
# 7   세종특별자치시  비수도권    384276.5   18091.0   26644.0   27710.0   22129.5
# 8       경기도   수도권  13545542.5  414094.0  600617.5  671466.5  650517.0
# 9       강원도  비수도권   1526763.0   39645.5   53774.5   63967.0   66508.0
# 10     충청북도  비수도권   1589702.0   42975.5   63368.5   72892.0   72168.5
# 11     충청남도  비수도권   2119950.5   59200.5   88889.5  102580.0   99448.0
# 12     전라북도  비수도권   1757041.0   40571.5   65841.5   81530.5   84276.0
# 13     전라남도  비수도권   1806802.0   45142.5   66124.0   80188.0   79963.5
# 14     경상북도  비수도권   2558213.5   62519.5   95650.0  109478.0  108890.5
# 15     경상남도  비수도권   3255461.0   82778.5  138123.5  161760.5  155474.0
# 16  제주특별자치도  비수도권    673099.0   20624.5   32454.5   36566.0   34044.0
#
#     20 - 24세  25 - 29세  30 - 34세  ...  70 - 74세  75 - 79세    80세 이상  80 - 84세  \
# 0   564693.5  802843.5  764498.5  ...  409781.0  311120.5  372713.5  222881.5
# 1   177426.5  208199.5  200972.0  ...  184261.0  129523.0  154773.0   94504.0
# 2   137540.5  150989.0  143435.5  ...  113543.0   77986.0  106327.5   62908.5
# 3   163436.0  205728.5  209312.0  ...  110819.0   81399.0  106370.5   60135.5
# 4    93358.0  100970.0   88568.0  ...   55494.0   41910.0   54074.0   31736.5
# 5    92828.5  108309.0   97767.5  ...   56734.5   40211.0   54537.5   31267.0
# 6    57363.0   68305.5   68602.0  ...   42883.0   26278.5   30852.5   18492.0
# 7    17677.5   20367.0   27577.0  ...    9696.0    6348.0    9609.0    5109.5
# 8   772182.5  932864.0  943400.0  ...  470060.5  354344.0  473734.5  269574.0
# 9    81638.0   84848.0   80114.5  ...   75982.0   63703.5   95323.5   54346.0
# 10   85105.0   99538.5   94101.0  ...   72032.0   53944.5   85364.5   47518.0
# 11  109083.0  118819.0  121990.5  ...  100723.0   75262.0  128397.0   68028.0
# 12   97457.0   96652.5   86046.0  ...   95279.5   74632.0  120400.5   66007.5
# 13   89983.0   91751.5   82775.0  ...  104199.5   84907.0  142380.5   79794.5
# 14  123978.5  129618.0  127606.0  ...  146629.0  101904.5  170248.5   94895.0
# 15  161774.5  169561.0  170191.0  ...  155149.5  108676.0  160931.5   90282.5
# 16   36126.5   39559.0   38327.5  ...   25770.0   21353.0   31423.0   16488.5
#
#       85세 이상  85 - 89세  90 - 94세  95 - 99세  100세 이상        비율
# 0   149832.0  105271.0   35320.5    7997.0   1243.5  0.182516
# 1    60269.0   43269.5   13677.5    2927.5    394.5  0.064352
# 2    43419.0   31388.5    9946.0    1837.5    247.0  0.046388
# 3    46235.0   31607.0   11530.5    2665.5    432.0  0.058010
# 4    22337.5   15645.5    5395.5    1114.0    182.5  0.027775
# 5    23270.5   16261.5    5618.5    1198.5    192.0  0.028132
# 6    12360.5    8724.5    2944.0     624.0     68.0  0.021582
# 7     4499.5    3023.5    1191.5     248.0     36.5  0.007513
# 8   204160.5  142329.0   49266.5   10889.5   1675.5  0.264841
# 9    40977.5   28362.5    9848.5    2410.5    356.0  0.029851
# 10   37846.5   26922.5    8875.0    1789.0    260.0  0.031082
# 11   60369.0   42039.5   14917.5    2954.0    458.0  0.041449
# 12   54393.0   37743.5   13449.5    2746.5    453.5  0.034354
# 13   62586.0   43387.0   15525.0    3115.5    558.5  0.035326
# 14   75353.5   53009.5   18147.0    3672.0    525.0  0.050018
# 15   70649.0   49625.5   17298.0    3320.5    405.0  0.063650
# 16   14934.5    9956.0    3938.5     783.5    256.5  0.013160
#
# [17 rows x 27 columns]

# %%
# 시도별 인구 분포
fig = px.choropleth_mapbox(data_frame=df_2, geojson=geo_json,
                           featureidkey="properties.CTP_KOR_NM",
                           locations=df_2['도시'], color=df_2['비율']*5,
                           color_continuous_scale='Blues',
                           range_color=(0, 1),
                           opacity=0.5, zoom=5.5,
                           center={"lat": 36, "lon": 127.5},
                           mapbox_style="carto-positron"
                           )
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1766a19d-e8e0-47f6-ae1c-dd1d00dce5fd" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1766a19d-e8e0-47f6-ae1c-dd1d00dce5fd")) {                    Plotly.newPlot(                        "1766a19d-e8e0-47f6-ae1c-dd1d00dce5fd",                        [{"coloraxis":"coloraxis","featureidkey":"properties.CTP_KOR_NM","geojson":{"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[126.984,37.636],[126.948,37.657],[126.912,37.644],[126.897,37.589],[126.854,37.574],[126.801,37.59],[126.772,37.548],[126.821,37.541],[126.819,37.479],[126.872,37.485],[126.903,37.434],[126.959,37.439],[127.003,37.467],[127.071,37.432],[127.127,37.469],[127.131,37.468],[127.132,37.468],[127.132,37.469],[127.132,37.47],[127.133,37.471],[127.133,37.472],[127.133,37.474],[127.133,37.475],[127.134,37.475],[127.135,37.474],[127.136,37.474],[127.144,37.474],[127.144,37.475],[127.144,37.476],[127.147,37.477],[127.148,37.482],[127.156,37.488],[127.155,37.488],[127.156,37.489],[127.158,37.489],[127.159,37.49],[127.157,37.49],[127.142,37.516],[127.176,37.575],[127.129,37.566],[127.096,37.689],[127.015,37.701],[126.98,37.656],[126.984,37.636]]]},"properties":{"CTPRVN_CD":"11","CTP_ENG_NM":"Seoul","CTP_KOR_NM":"\uc11c\uc6b8\ud2b9\ubcc4\uc2dc"}},{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[129.288,35.321],[129.263,35.386],[129.219,35.379],[129.178,35.352],[129.149,35.364],[129.112,35.31],[129.045,35.275],[129.017,35.275],[128.999,35.238],[128.886,35.214],[128.881,35.183],[128.843,35.158],[128.838,35.083],[128.895,35.079],[128.933,35.095],[128.958,35.051],[129.022,35.062],[129.025,35.094],[129.067,35.108],[129.113,35.103],[129.12,35.154],[129.181,35.155],[129.224,35.186],[129.222,35.213],[129.253,35.247],[129.268,35.322],[129.288,35.321]]]},"properties":{"CTPRVN_CD":"26","CTP_ENG_NM":"Busan","CTP_KOR_NM":"\ubd80\uc0b0\uad11\uc5ed\uc2dc"}},{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[128.473,35.833],[128.47,35.806],[128.421,35.809],[128.383,35.759],[128.432,35.726],[128.412,35.696],[128.357,35.682],[128.4,35.646],[128.506,35.64],[128.528,35.713],[128.581,35.739],[128.624,35.703],[128.683,35.721],[128.695,35.756],[128.683,35.79],[128.709,35.827],[128.76,35.866],[128.738,35.928],[128.746,35.973],[128.696,36.016],[128.617,36.007],[128.546,35.966],[128.529,35.924],[128.475,35.894],[128.476,35.934],[128.431,35.931],[128.398,35.893],[128.384,35.853],[128.436,35.848],[128.473,35.834],[128.473,35.833]]]},"properties":{"CTPRVN_CD":"27","CTP_ENG_NM":"Daegu","CTP_KOR_NM":"\ub300\uad6c\uad11\uc5ed\uc2dc"}},{"type":"Feature","geometry":{"type":"MultiPolygon","coordinates":[[[[126.343,37.644],[126.375,37.669],[126.363,37.696],[126.316,37.685],[126.343,37.644]]],[[[126.601,37.416],[126.61,37.387],[126.663,37.351],[126.721,37.383],[126.769,37.428],[126.777,37.472],[126.745,37.514],[126.787,37.586],[126.726,37.592],[126.672,37.634],[126.626,37.603],[126.64,37.585],[126.597,37.549],[126.608,37.487],[126.601,37.416]]],[[[126.541,37.521],[126.512,37.534],[126.471,37.498],[126.417,37.496],[126.356,37.468],[126.38,37.44],[126.443,37.422],[126.508,37.466],[126.583,37.491],[126.541,37.521]]],[[[126.439,37.231],[126.496,37.256],[126.471,37.285],[126.435,37.273],[126.439,37.231]]],[[[126.265,37.818],[126.223,37.805],[126.216,37.778],[126.291,37.763],[126.298,37.802],[126.265,37.818]]],[[[126.431,37.83],[126.351,37.79],[126.356,37.707],[126.392,37.694],[126.413,37.656],[126.377,37.636],[126.403,37.594],[126.511,37.597],[126.543,37.618],[126.523,37.652],[126.514,37.725],[126.526,37.747],[126.507,37.782],[126.431,37.83]]],[[[124.687,37.98],[124.623,37.957],[124.637,37.924],[124.696,37.917],[124.73,37.978 ...

# %%
df_2_group=df_2.groupby(['지역']).sum().reset_index()
df_2_group = df_2_group.reindex([1, 0])
df_2_group
# Out:
# <ipython-input-22-c0f5b3ccd782>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#      지역           계    0 - 4세     5 - 9세   10 - 14세   15 - 19세   20 - 24세  \
# 1   수도권  25847455.0  718493.5  1030677.5  1166476.0  1166535.0  1500312.0
# 0  비수도권  25298429.5  662311.0  1019557.5  1175043.0  1162747.0  1361339.5
#
#     25 - 29세   30 - 34세   35 - 39세  ...   70 - 74세  75 - 79세     80세 이상  \
# 1  1941436.0  1917210.5  1780791.0  ...   990660.5  746863.5   952818.5
# 0  1487487.5  1428073.5  1440575.0  ...  1238376.0  906639.0  1344642.5
#
#    80 - 84세    85세 이상  85 - 89세  90 - 94세  95 - 99세  100세 이상        비율
# 1  552591.0  400227.5  279207.0   96117.5   21552.0   3351.0  0.505367
# 0  761377.5  583265.0  409359.0  140772.0   28741.0   4393.0  0.494633
#
# [2 rows x 26 columns]

# %%
df_2_group['10세 미만'] = df_2_group['0 - 4세'] + df_2_group['5 - 9세']
df_2_group['10대'] = df_2_group['10 - 14세'] + df_2_group['15 - 19세']
df_2_group['20대'] = df_2_group['20 - 24세'] + df_2_group['25 - 29세']
df_2_group['30대'] = df_2_group['30 - 34세'] + df_2_group['35 - 39세']
df_2_group['40대'] = df_2_group['40 - 44세'] + df_2_group['45 - 49세']
df_2_group['50대'] = df_2_group['50 - 54세'] + df_2_group['55 - 59세']
df_2_group['60대'] = df_2_group['60 - 64세'] + df_2_group['65 - 69세']
df_2_group['70대'] = df_2_group['70 - 74세'] + df_2_group['75 - 79세']
df_2_group['80대'] = df_2_group['80 - 84세'] + df_2_group['85 - 89세']
df_2_group['90대'] = df_2_group['90 - 94세'] + df_2_group['95 - 99세']

# %%
df_2_group = df_2_group[['지역','10세 미만','10대','20대','30대','40대','50대','60대','70대','80대','90대','100세 이상']]
df_2_group
# Out:
#      지역     10세 미만        10대        20대        30대        40대        50대  \
# 1   수도권  1749171.0  2333011.0  3441748.0  3698001.5  4155268.0  4280094.0
# 0  비수도권  1681868.5  2337790.0  2848827.0  2868648.5  3790777.0  4308227.0
#
#          60대        70대        80대       90대  100세 이상
# 1  3499819.0  1737524.0   831798.0  117669.5   3351.0
# 0  3972634.0  2145015.0  1170736.5  169513.0   4393.0

# %%
# 지역별/연령별 인구수
fig = go.Figure()

colors = {
    '10세 미만': 'skyblue',
    '10대': 'skyblue',
    '20대': 'rgb(100,100,300)',
    '30대': 'rgb(100,100,300)',
    '40대': 'rgb(100,100,300)',
    '50대': 'skyblue',
    '60대': 'rgb(150,150,450)',
    '70대': 'rgb(150,150,450)',
    '80대': 'rgb(150,150,450)',
    '90대': 'rgb(150,150,450)',
    '100세 이상': 'rgb(150,150,450)',
}

for column in df_2_group.columns[1:]:
    fig.add_trace(go.Bar(
        x=df_2_group['지역'],
        y=df_2_group[column],
        name=column,
        marker_color=colors[column],
        text=round(df_2_group[column]/1000000,1)
    ))

fig.update_layout(barmode='group')
fig.update_layout(
    autosize=False,
    width=1200,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="77bc551e-136e-4c59-a53f-a9850674ec5f" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77bc551e-136e-4c59-a53f-a9850674ec5f")) {                    Plotly.newPlot(                        "77bc551e-136e-4c59-a53f-a9850674ec5f",                        [{"marker":{"color":"skyblue"},"name":"10\uc138 \ubbf8\ub9cc","text":[1.7,1.7],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[1749171.0,1681868.5],"type":"bar"},{"marker":{"color":"skyblue"},"name":"10\ub300","text":[2.3,2.3],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[2333011.0,2337790.0],"type":"bar"},{"marker":{"color":"rgb(100,100,300)"},"name":"20\ub300","text":[3.4,2.8],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[3441748.0,2848827.0],"type":"bar"},{"marker":{"color":"rgb(100,100,300)"},"name":"30\ub300","text":[3.7,2.9],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[3698001.5,2868648.5],"type":"bar"},{"marker":{"color":"rgb(100,100,300)"},"name":"40\ub300","text":[4.2,3.8],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[4155268.0,3790777.0],"type":"bar"},{"marker":{"color":"skyblue"},"name":"50\ub300","text":[4.3,4.3],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[4280094.0,4308227.0],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"60\ub300","text":[3.5,4.0],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[3499819.0,3972634.0],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"70\ub300","text":[1.7,2.1],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[1737524.0,2145015.0],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"80\ub300","text":[0.8,1.2],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[831798.0,1170736.5],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"90\ub300","text":[0.1,0.2],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[117669.5,169513.0],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"100\uc138 \uc774\uc0c1","text":[0.0,0.0],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[3351.0,4393.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %%
df_2_group['60세 미만'] = df_2_group[['10세 미만', '10대', '20대', '30대', '40대', '50대']].sum(axis=1)
df_2_group['60세 이상'] = df_2_group[['60대', '70대', '80대', '90대', '100세 이상']].sum(axis=1)
df_2_group
# Out:
# <ipython-input-26-f30ede39c531>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-26-f30ede39c531>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      지역     10세 미만        10대        20대        30대        40대        50대  \
# 1   수도권  1749171.0  2333011.0  3441748.0  3698001.5  4155268.0  4280094.0
# 0  비수도권  1681868.5  2337790.0  2848827.0  2868648.5  3790777.0  4308227.0
#
#          60대        70대        80대       90대  100세 이상      60세 미만     60세 이상
# 1  3499819.0  1737524.0   831798.0  117669.5   3351.0  19657293.5  6190161.5
# 0  3972634.0  2145015.0  1170736.5  169513.0   4393.0  17836138.0  7462291.5

# %%
df_2_group = df_2_group[['지역','60세 미만', '60세 이상']]

# %%
df_2_group_cap=df_2_group[df_2_group['지역']=='수도권']
df_2_group_oth=df_2_group[df_2_group['지역']=='비수도권']

# %%
df_2_group_cap
# Out:
#     지역      60세 미만     60세 이상
# 1  수도권  19657293.5  6190161.5

# %%
df_2_group_oth
# Out:
#      지역      60세 미만     60세 이상
# 0  비수도권  17836138.0  7462291.5

# %%
labels = ['60세 미만', '60세 이상']
values = [df_2_group_cap['60세 미만'].iloc[0], df_2_group_cap['60세 이상'].iloc[0]]
colors = ['rgb(150, 150, 450)', 'rgb(100, 100, 300)']

fig = go.Figure(data=[go.Pie(labels=labels, values=values,
                             marker=dict(colors=colors))])

fig.update_layout(barmode='group')
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ecb23ee2-df87-471b-81eb-97fd5897ecc2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecb23ee2-df87-471b-81eb-97fd5897ecc2")) {                    Plotly.newPlot(                        "ecb23ee2-df87-471b-81eb-97fd5897ecc2",                        [{"labels":["60\uc138 \ubbf8\ub9cc","60\uc138 \uc774\uc0c1"],"marker":{"colors":["rgb(150, 150, 450)","rgb(100, 100, 300)"]},"values":[19657293.5,6190161.5],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}] ...

# %%
labels = ['60세 미만', '60세 이상']
values = [df_2_group_oth['60세 미만'].iloc[0], df_2_group_oth['60세 이상'].iloc[0]]
colors = ['rgb(150, 150, 450)', 'rgb(100, 100, 300)']

fig = go.Figure(data=[go.Pie(labels=labels, values=values,
                             marker=dict(colors=colors))])

fig.update_layout(barmode='group')
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f02a1a7-7ac1-4faa-8be1-0b78a7c5fbe5" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f02a1a7-7ac1-4faa-8be1-0b78a7c5fbe5")) {                    Plotly.newPlot(                        "6f02a1a7-7ac1-4faa-8be1-0b78a7c5fbe5",                        [{"labels":["60\uc138 \ubbf8\ub9cc","60\uc138 \uc774\uc0c1"],"marker":{"colors":["rgb(150, 150, 450)","rgb(100, 100, 300)"]},"values":[17836138.0,7462291.5],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}] ...

# %% [markdown]
# # 현황

# %% [markdown]
# ## 경제

# %%
economy_path = 'https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/economy.xlsx'
economy_df = pd.read_excel(economy_path)
economy_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#      시도별    2022 p) 2022 p).1
# 0    시도별  1인당 지역총소득  1인당 개인소득
# 1  서울특별시      57236     26112
# 2  부산광역시      32293     22577
# 3  대구광역시      31056     22368
# 4  인천광역시      37442     22406

# %%
new_columns = economy_df.iloc[0]
economy_df.columns = new_columns
economy_df = economy_df.drop(0)

# %%
economy_df.reset_index(inplace=True)

# %%
economy_df.drop(columns='index', inplace=True)

# %%
economy_df.rename(columns={'시도별':'도시'}, inplace=True)

economy_df['지역']='비수도권'
economy_df.loc[economy_df['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'
economy_df.insert(0, '지역', economy_df.pop('지역'))

# %%
economy_df.head()
# Out:
# 0    지역     도시 1인당 지역총소득 1인당 개인소득
# 0   수도권  서울특별시     57236    26112
# 1  비수도권  부산광역시     32293    22577
# 2  비수도권  대구광역시     31056    22368
# 3   수도권  인천광역시     37442    22406
# 4  비수도권  광주광역시     34844    23669

# %%
economy_df_group = economy_df.groupby('지역').mean().reset_index()
economy_df_group = economy_df_group.reindex([1, 0]).reset_index()
# Out:
# <ipython-input-39-a4796531664e>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
economy_df_group.drop(columns='index', inplace=True)

# %%
economy_df_group
# Out:
# 0    지역     1인당 지역총소득      1인당 개인소득
# 0   수도권  46104.333333  23884.666667
# 1  비수도권  38151.642857  22818.571429

# %%
# 지역별 1인당 평균 소득
fig = go.Figure()

fig.add_trace(go.Bar(x=economy_df_group['지역'],
                     y=economy_df_group['1인당 개인소득'],
                     text=round(economy_df_group['1인당 개인소득']),
                     marker_color='rgb(100,100,300)',
                     name='개인소득'))

fig.add_trace(go.Bar(x=economy_df_group['지역'],
                     y=(economy_df_group['1인당 지역총소득'] - economy_df_group['1인당 개인소득']),
                     text=round((economy_df_group['1인당 지역총소득'])),
                     marker_color='rgb(150,150,450)',
                     name='지역총소득'))

fig.update_layout(barmode='stack')

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d509d271-f3cd-4831-a613-07172ab05454" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d509d271-f3cd-4831-a613-07172ab05454")) {                    Plotly.newPlot(                        "d509d271-f3cd-4831-a613-07172ab05454",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uac1c\uc778\uc18c\ub4dd","text":[23885.0,22819.0],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[23884.666666666668,22818.571428571428],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"\uc9c0\uc5ed\ucd1d\uc18c\ub4dd","text":[46104.0,38152.0],"x":["\uc218\ub3c4\uad8c","\ube44\uc218\ub3c4\uad8c"],"y":[22219.666666666668,15333.071428571428],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatte ...

# %% [markdown]
# ## 교육

# %%
edu_path='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/edu.csv'

edu_df=pd.read_csv(edu_path, encoding='cp949')
edu_df.head()
# Out:
#       학교명                  학교 영문명 본분교구분명 대학구분명 학교구분명 설립형태구분명  시도코드    시도명  \
# 0   한신대학교      Hanshin University     본교    대학   대학교      사립    41    경기도
# 1   한세대학교       Hansei University     본교    대학   대학교      사립    41    경기도
# 2   성결대학교     Sungkyul University     본교    대학   대학교      사립    41    경기도
# 3   평택대학교   Pyeongtaek University     본교    대학   대학교      사립    41    경기도
# 4  성공회대학교  Sungkonghoe University     본교    대학   대학교      사립    11  서울특별시
#
#                             소재지도로명주소  소재지지번주소  도로명우편번호  소재지우편번호  \
# 0      경기도 오산시 한신대길 137 (양산동, 한신대학교)      NaN    18101      NaN
# 1               경기도 군포시 한세로 30 (당정동)      NaN    15852      NaN
# 2  경기도 안양시 만안구 성결대학로 53 (안양동, 성결대학교)      NaN    14097      NaN
# 3     경기도 평택시 서동대로 3825 (용이동, 평택대학교)      NaN    17869      NaN
# 4     서울특별시 구로구 연동로 320 (항동, 성공회대학교)      NaN     8359      NaN
#
#                홈페이지주소        대표전화번호        대표팩스번호        설립일자  기준연도  \
# 0        www.hs.ac.kr  031-379-0114  031-379-0039  1940-04-19  2022
# 1    www.hansei.ac.kr  031-450-5114  031-450-5124  1953-05-10  2022
# 2  www.sungkyul.ac.kr  031-467-8114  031-449-0529  1965-01-13  2022
# 3       www.ptu.ac.kr  031-659-8114  031-659-8011  1990-11-28  2022
# 4      www.skhu.ac.kr  02-2610-4114  02-2610-4248  1992-12-23  2022
#
#       데이터기준일자   제공기관코드      제공기관명
# 0  2023-12-27  B340014  한국대학교육협의회
# 1  2023-12-27  B340014  한국대학교육협의회
# 2  2023-12-27  B340014  한국대학교육협의회
# 3  2023-12-27  B340014  한국대학교육협의회
# 4  2023-12-27  B340014  한국대학교육협의회

# %%
edu_df_count = edu_df.groupby('시도명').agg(대학=pd.NamedAgg(column='대학구분명', aggfunc=lambda x: x.eq('대학').sum()),
                                     전문대학=pd.NamedAgg(column='대학구분명', aggfunc=lambda x: x.eq('전문대학').sum())).reset_index()

# %%
edu_df_count.rename(columns={'시도명':'도시'}, inplace=True)

# %%
edu_df_count['지역']='비수도권'
edu_df_count.loc[edu_df_count['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'
edu_df_count.insert(0, '지역', edu_df_count.pop('지역'))

# %%
edu_df_count['합계']=edu_df_count['대학']+edu_df_count['전문대학']

# %%
edu_df_count.loc[edu_df_count['도시'] == '강원특별자치도', '도시'] = '강원도'

# %%
edu_df_count
# Out:
#       지역       도시  대학  전문대학  합계
# 0   비수도권      강원도  14    13  27
# 1    수도권      경기도  40    37  77
# 2   비수도권     경상남도  11    14  25
# 3   비수도권     경상북도  22    20  42
# 4   비수도권    광주광역시  11     7  18
# 5   비수도권    대구광역시   4    10  14
# 6   비수도권    대전광역시  15     5  20
# 7   비수도권    부산광역시  17    12  29
# 8    수도권    서울특별시  57    12  69
# 9   비수도권  세종특별자치시   3     1   4
# 10  비수도권    울산광역시   2     3   5
# 11   수도권    인천광역시   6     6  12
# 12  비수도권     전라남도  12    11  23
# 13  비수도권     전라북도  12    11  23
# 14  비수도권  제주특별자치도   3     4   7
# 15  비수도권     충청남도  20     9  29
# 16  비수도권     충청북도  13     6  19

# %%
# 지역별 대학/전문대학 수
edu_df_count_cap=edu_df_count[edu_df_count['지역']=='수도권']
edu_df_count_oth=edu_df_count[edu_df_count['지역']=='비수도권']

fig = go.Figure()

fig.add_trace(go.Bar(x=edu_df_count_cap['도시'],
                     y=edu_df_count_cap['합계'],
                     name='수도권',
                     marker_color="rgb(100,100,300)",
                     text=edu_df_count_cap['합계']))

fig.add_trace(go.Bar(x=edu_df_count_oth['도시'],
                     y=edu_df_count_oth['합계'],
                     name='비수도권',
                     marker_color="rgb(150,150,450)",
                     text=edu_df_count_oth['합계']))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="56bf63c2-e5f4-4ab1-921b-6549a16ebb61" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56bf63c2-e5f4-4ab1-921b-6549a16ebb61")) {                    Plotly.newPlot(                        "56bf63c2-e5f4-4ab1-921b-6549a16ebb61",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uc218\ub3c4\uad8c","text":[77.0,69.0,12.0],"x":["\uacbd\uae30\ub3c4","\uc11c\uc6b8\ud2b9\ubcc4\uc2dc","\uc778\ucc9c\uad11\uc5ed\uc2dc"],"y":[77,69,12],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"\ube44\uc218\ub3c4\uad8c","text":[27.0,25.0,42.0,18.0,14.0,20.0,29.0,4.0,5.0,23.0,23.0,7.0,29.0,19.0],"x":["\uac15\uc6d0\ub3c4","\uacbd\uc0c1\ub0a8\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\uad11\uc8fc\uad11\uc5ed\uc2dc","\ub300\uad6c\uad11\uc5ed\uc2dc","\ub300\uc804\uad11\uc5ed\uc2dc","\ubd80\uc0b0\uad11\uc5ed\uc2dc","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc804\ub77c\ub0a8\ub3c4","\uc804\ub77c\ubd81\ub3c4","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4","\ucda9\uccad\ub0a8\ub3c4","\ucda9\uccad\ubd81\ub3c4"],"y":[27,25,42,18,14,20,29,4,5,23,23,7,29,19],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":1 ...

# %% [markdown]
# ## 교통

# %%
trafic_path='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/trafic.xlsx'

trafic_df=pd.read_excel(trafic_path)
trafic_df
# Out:
#    시도코드       시도       년  교통수단         발생량         도착량
# 0    합계      NaN     NaN   NaN  7980291016  6967827119
# 1    11    서울특별시  2023.0    좌석     1917876     1850621
# 2   NaN    서울특별시     NaN    시내  1294222753  1265833029
# 3   NaN    서울특별시     NaN    마을   299405042   293266980
# 4   NaN    서울특별시     NaN  도시철도  1896284027  1899827451
# ..  ...      ...     ...   ...         ...         ...
# 74   51  강원특별자치도  2023.0    좌석      254956       59161
# 75  NaN  강원특별자치도     NaN    시내    22547474     9188182
# 76  NaN  강원특별자치도     NaN    마을      882634      381813
# 77  NaN  강원특별자치도     NaN  도시철도     1233575     1189884
# 78  NaN  강원특별자치도     NaN    광역         268           0
#
# [79 rows x 6 columns]

# %%
trafic_df.drop(columns='시도코드' ,inplace=True)
trafic_df.drop(columns='도착량', inplace=True)
trafic_df.drop(columns='년', inplace=True)

# %%
trafic_df_group=trafic_df.groupby('시도')['발생량'].sum().reset_index()

# %%
trafic_df_group = trafic_df_group.append({'시도':'강원도',
                                          '발생량':trafic_df_group[trafic_df_group['시도']=='강원도']['발생량'].values[0]+trafic_df_group[trafic_df_group['시도']=='강원특별자치도']['발생량'].values[0]}, ignore_index=True)
# Out:
# <ipython-input-54-72bba936596a>:1: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
trafic_df_group.drop(0, inplace=True)
trafic_df_group.drop(1, inplace=True)

# %%
trafic_df_group.rename(columns={'시도':'도시'}, inplace=True)

# %%
trafic_df_group['지역']='비수도권'
trafic_df_group.loc[trafic_df_group['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'
trafic_df_group.insert(0, '지역', trafic_df_group.pop('지역'))

# %%
trafic_df_group=trafic_df_group.sort_values('도시').reset_index()

# %%
trafic_df_group.drop(columns='index', inplace=True)

# %%
trafic_df_group.rename(columns={'발생량':'대중교통이용량'}, inplace=True)

# %%
trafic_df_group
# Out:
#       지역       도시     대중교통이용량
# 0   비수도권      강원도    43955463
# 1    수도권      경기도  1833395164
# 2   비수도권     경상남도   165651483
# 3   비수도권     경상북도    91492652
# 4   비수도권    광주광역시   117909907
# 5   비수도권    대구광역시   301327052
# 6   비수도권    대전광역시   167168410
# 7   비수도권    부산광역시   765840871
# 8    수도권    서울특별시  3577353202
# 9   비수도권  세종특별자치시    19927506
# 10  비수도권    울산광역시    80092990
# 11   수도권    인천광역시   479459277
# 12  비수도권     전라남도    61940848
# 13  비수도권     전라북도    62148192
# 14  비수도권  제주특별자치도    53649528
# 15  비수도권     충청남도    99828301
# 16  비수도권     충청북도    59150170

# %%
trafic_df_group_cap=trafic_df_group[trafic_df_group['지역']=='수도권']
trafic_df_group_oth=trafic_df_group[trafic_df_group['지역']=='비수도권']

# %%
# 시도별 대중교통 이용 수
fig = go.Figure()

fig.add_trace(go.Bar(x=trafic_df_group_cap['도시'],
                     y=trafic_df_group_cap['대중교통이용량'],
                     name='수도권',
                     marker_color="rgb(100,100,300)",
                     text=round(trafic_df_group_cap['대중교통이용량']/1000000000,2)))

fig.add_trace(go.Bar(x=trafic_df_group_oth['도시'],
                     y=trafic_df_group_oth['대중교통이용량'],
                     name='비수도권',
                     marker_color="rgb(150,150,450)",
                     text=round(trafic_df_group_oth['대중교통이용량']/1000000000,2)))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7bd26012-b473-43aa-9137-5eaa4acb0e24" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bd26012-b473-43aa-9137-5eaa4acb0e24")) {                    Plotly.newPlot(                        "7bd26012-b473-43aa-9137-5eaa4acb0e24",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uc218\ub3c4\uad8c","text":[1.83,3.58,0.48],"x":["\uacbd\uae30\ub3c4","\uc11c\uc6b8\ud2b9\ubcc4\uc2dc","\uc778\ucc9c\uad11\uc5ed\uc2dc"],"y":[1833395164,3577353202,479459277],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"\ube44\uc218\ub3c4\uad8c","text":[0.04,0.17,0.09,0.12,0.3,0.17,0.77,0.02,0.08,0.06,0.06,0.05,0.1,0.06],"x":["\uac15\uc6d0\ub3c4","\uacbd\uc0c1\ub0a8\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\uad11\uc8fc\uad11\uc5ed\uc2dc","\ub300\uad6c\uad11\uc5ed\uc2dc","\ub300\uc804\uad11\uc5ed\uc2dc","\ubd80\uc0b0\uad11\uc5ed\uc2dc","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc804\ub77c\ub0a8\ub3c4","\uc804\ub77c\ubd81\ub3c4","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4","\ucda9\uccad\ub0a8\ub3c4","\ucda9\uccad\ubd81\ub3c4"],"y":[43955463,165651483,91492652,117909907,301327052,167168410,765840871,19927506,80092990,61940848,62148192,53649528,99828301,59150170],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[ ...

# %% [markdown]
# ## 인구

# %%
peo_path='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/people.xlsx'

peo_df = pd.read_excel(peo_path)
peo_df.head()
# Out:
#        시점 행정구역(시군구)별 성별          계    0 - 4세    5 - 9세  10 - 14세  15 - 19세  \
# 0  2023.0      서울특별시  계  9334933.5  220265.5  308678.0  357808.5  381243.0
# 1  2023.0      부산광역시  계    3291326   78305.5  121997.0  133933.5  130393.0
# 2  2023.0      대구광역시  계    2372562   59547.0   94764.0  106649.0  109453.5
# 3  2023.0      인천광역시  계    2966979   84134.0  121382.0  137201.0  134775.0
# 4  2023.0      광주광역시  계    1420562   40702.5   62653.5   73565.0   75537.0
#
#    20 - 24세  25 - 29세  ...  65 - 69세  70 - 74세  75 - 79세    80세 이상  80 - 84세  \
# 0  564693.5  802843.5  ...  588956.0  409781.0  311120.5  372713.5  222881.5
# 1  177426.5  208199.5  ...  258134.5  184261.0  129523.0  154773.0   94504.0
# 2  137540.5  150989.0  ...  157212.0  113543.0   77986.0  106327.5   62908.5
# 3  163436.0  205728.5  ...  179728.5  110819.0   81399.0  106370.5   60135.5
# 4   93358.0  100970.0  ...   76434.0   55494.0   41910.0   54074.0   31736.5
#
#      85세 이상  85 - 89세  90 - 94세  95 - 99세  100세 이상
# 0  149832.0  105271.0   35320.5    7997.0   1243.5
# 1   60269.0   43269.5   13677.5    2927.5    394.5
# 2   43419.0   31388.5    9946.0    1837.5    247.0
# 3   46235.0   31607.0   11530.5    2665.5    432.0
# 4   22337.5   15645.5    5395.5    1114.0    182.5
#
# [5 rows x 27 columns]

# %%
peo_df.rename(columns={'행정구역(시군구)별':'도시',
                       '계':'인구수'}, inplace=True)

# %%
peo_df=peo_df[['도시','인구수']]

# %%
peo_df['지역']='비수도권'
peo_df.loc[peo_df['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'
peo_df.insert(0, '지역', peo_df.pop('지역'))
# Out:
# <ipython-input-67-cc03e43e5f10>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
peo_df=peo_df.drop(17)

# %%
peo_df
# Out:
#       지역       도시         인구수
# 0    수도권    서울특별시   9334933.5
# 1   비수도권    부산광역시     3291326
# 2   비수도권    대구광역시     2372562
# 3    수도권    인천광역시     2966979
# 4   비수도권    광주광역시     1420562
# 5   비수도권    대전광역시     1438846
# 6   비수도권    울산광역시     1103825
# 7   비수도권  세종특별자치시    384276.5
# 8    수도권      경기도  13545542.5
# 9   비수도권      강원도     1526763
# 10  비수도권     충청북도     1589702
# 11  비수도권     충청남도   2119950.5
# 12  비수도권     전라북도     1757041
# 13  비수도권     전라남도     1806802
# 14  비수도권     경상북도   2558213.5
# 15  비수도권     경상남도     3255461
# 16  비수도권  제주특별자치도      673099

# %%
peo_df['인구수'] = peo_df['인구수'].astype(float)

# %%
peo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      17 non-null     object
#  1   도시      17 non-null     object
#  2   인구수     17 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 536.0+ bytes

# %%
peo_df['인구수'].sum()
# Out:
# 51145884.5

# %%
# 지역별 인구수
peo_df_cap=peo_df[peo_df['지역']=='수도권']
peo_df_oth=peo_df[peo_df['지역']=='비수도권']

fig = go.Figure()

fig.add_trace(go.Bar(x=peo_df_cap['도시'],
                     y=peo_df_cap['인구수'],
                     name='수도권',
                     marker_color="rgb(100,100,300)",
                     text=round(peo_df_cap['인구수']/1000000,1)))

fig.add_trace(go.Bar(x=peo_df_oth['도시'],
                     y=peo_df_oth['인구수'],
                     name='비수도권',
                     marker_color="rgb(150,150,450)",
                     text=round(peo_df_oth['인구수']/1000000,1)))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6cd7f488-1092-4c9f-9e3b-af433f46f029" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cd7f488-1092-4c9f-9e3b-af433f46f029")) {                    Plotly.newPlot(                        "6cd7f488-1092-4c9f-9e3b-af433f46f029",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uc218\ub3c4\uad8c","text":[9.3,3.0,13.5],"x":["\uc11c\uc6b8\ud2b9\ubcc4\uc2dc","\uc778\ucc9c\uad11\uc5ed\uc2dc","\uacbd\uae30\ub3c4"],"y":[9334933.5,2966979.0,13545542.5],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"\ube44\uc218\ub3c4\uad8c","text":[3.3,2.4,1.4,1.4,1.1,0.4,1.5,1.6,2.1,1.8,1.8,2.6,3.3,0.7],"x":["\ubd80\uc0b0\uad11\uc5ed\uc2dc","\ub300\uad6c\uad11\uc5ed\uc2dc","\uad11\uc8fc\uad11\uc5ed\uc2dc","\ub300\uc804\uad11\uc5ed\uc2dc","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc","\uac15\uc6d0\ub3c4","\ucda9\uccad\ubd81\ub3c4","\ucda9\uccad\ub0a8\ub3c4","\uc804\ub77c\ubd81\ub3c4","\uc804\ub77c\ub0a8\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\uacbd\uc0c1\ub0a8\ub3c4","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4"],"y":[3291326.0,2372562.0,1420562.0,1438846.0,1103825.0,384276.5,1526763.0,1589702.0,2119950.5,1757041.0,1806802.0,2558213.5,3255461.0,673099.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type": ...

# %% [markdown]
# ## 의료

# %%
med_path='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/med.xlsx'

med_df=pd.read_excel(med_path)
med_df
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#      시도별(1)      2022
# 0    시도별(1)        총계
# 1    시도별(1)  기관수 (개소)
# 2     서울특별시        26
# 3     부산광역시        10
# 4     대구광역시         9
# 5     인천광역시         8
# 6     광주광역시        10
# 7     대전광역시         8
# 8     울산광역시         1
# 9   세종특별자치시         1
# 10      경기도        32
# 11  강원특별자치도        18
# 12     충청북도        12
# 13     충청남도        10
# 14     전라북도        12
# 15     전라남도        22
# 16     경상북도        26
# 17     경상남도        21
# 18  제주특별자치도         5

# %%
med_df.rename(columns={'시도별(1)':'도시',
                         '2022':'의료기관수'}, inplace=True)

# %%
med_df.drop(0, inplace=True)

# %%
med_df.drop(1, inplace=True)

# %%
med_df=med_df.reset_index()

# %%
med_df=med_df.drop(columns='index')

# %%
med_df['지역']='비수도권'
med_df.loc[med_df['도시'].isin(['서울특별시', '인천광역시', '경기도']), '지역'] = '수도권'
med_df.insert(0, '지역', med_df.pop('지역'))

# %%
med_df.loc[med_df['도시'] == '강원특별자치도', '도시'] = '강원도'

# %%
med_df
# Out:
#       지역       도시 의료기관수
# 0    수도권    서울특별시    26
# 1   비수도권    부산광역시    10
# 2   비수도권    대구광역시     9
# 3    수도권    인천광역시     8
# 4   비수도권    광주광역시    10
# 5   비수도권    대전광역시     8
# 6   비수도권    울산광역시     1
# 7   비수도권  세종특별자치시     1
# 8    수도권      경기도    32
# 9   비수도권      강원도    18
# 10  비수도권     충청북도    12
# 11  비수도권     충청남도    10
# 12  비수도권     전라북도    12
# 13  비수도권     전라남도    22
# 14  비수도권     경상북도    26
# 15  비수도권     경상남도    21
# 16  비수도권  제주특별자치도     5

# %%
med_df['의료기관수'].sum()
# Out:
# 231

# %%
# 지역별 공공의료기관 수
med_df_cap=med_df[med_df['지역']=='수도권']
med_df_oth=med_df[med_df['지역']=='비수도권']

fig = go.Figure()

fig.add_trace(go.Bar(x=med_df_cap['도시'],
                     y=med_df_cap['의료기관수'],
                     name='수도권',
                     marker_color="rgb(100,100,300)",
                     text=med_df_cap['의료기관수']))

fig.add_trace(go.Bar(x=med_df_oth['도시'],
                     y=med_df_oth['의료기관수'],
                     name='비수도권',
                     marker_color="rgb(150,150,450)",
                     text=med_df_oth['의료기관수']))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd881431-7f33-4ba0-a44a-5eaaa117383d" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd881431-7f33-4ba0-a44a-5eaaa117383d")) {                    Plotly.newPlot(                        "cd881431-7f33-4ba0-a44a-5eaaa117383d",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uc218\ub3c4\uad8c","text":[26,8,32],"x":["\uc11c\uc6b8\ud2b9\ubcc4\uc2dc","\uc778\ucc9c\uad11\uc5ed\uc2dc","\uacbd\uae30\ub3c4"],"y":[26,8,32],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"\ube44\uc218\ub3c4\uad8c","text":[10,9,10,8,1,1,18,12,10,12,22,26,21,5],"x":["\ubd80\uc0b0\uad11\uc5ed\uc2dc","\ub300\uad6c\uad11\uc5ed\uc2dc","\uad11\uc8fc\uad11\uc5ed\uc2dc","\ub300\uc804\uad11\uc5ed\uc2dc","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc","\uac15\uc6d0\ub3c4","\ucda9\uccad\ubd81\ub3c4","\ucda9\uccad\ub0a8\ub3c4","\uc804\ub77c\ubd81\ub3c4","\uc804\ub77c\ub0a8\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\uacbd\uc0c1\ub0a8\ub3c4","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4"],"y":[10,9,10,8,1,1,18,12,10,12,22,26,21,5],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"pa ...

# %% [markdown]
# ## 주거

# %%
house_path='https://raw.githubusercontent.com/UBDBD/Regional-deviation-analysis/main/Data/house.xlsx'

house_df = pd.read_excel(house_path)
house_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#   시도별(1) 시도별(2)  2023.01  2023.02  2023.03  2023.04  2023.05  2023.06  \
# 0    수도권     소계     83.2     94.1     97.0     99.0    103.3    104.3
# 1    수도권  서울특별시     82.1     93.3     97.7    100.0    104.6    107.2
# 2    수도권  인천광역시     84.7     95.6     94.4     95.0     97.1    100.1
# 3    수도권    경기도     83.4     94.2     97.1     99.3    104.0    103.5
# 4   비수도권     소계     84.7     93.5     94.0     97.7     99.4    101.8
#
#    2023.07  2023.08  2023.09  2023.10  2023.11  2023.12
# 0    108.7    111.8    113.4    106.2     99.2     96.8
# 1    111.1    114.8    116.9    110.3    101.6     98.4
# 2    102.9    104.4    107.7    101.8     96.1     96.2
# 3    108.7    111.7    112.6    104.7     98.4     96.0
# 4    103.3    106.6    107.7    103.2     97.5     96.1

# %%
house_df=house_df.rename(columns={'시도별(1)':'지역',
                        '시도별(2)':'도시'})

# %%
house_df['평균']=house_df.mean(axis='columns')
house_df.insert(2, '평균', house_df.pop('평균'))
# Out:
# <ipython-input-87-cd4743f67bab>:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
house_df.drop([0,4], axis=0, inplace=True)

# %%
house_df.loc[house_df['도시'] == '강원특별자치도', '도시'] = '강원도'

# %%
house_df
# Out:
#       지역       도시          평균  2023.01  2023.02  2023.03  2023.04  2023.05  \
# 1    수도권    서울특별시  103.166667     82.1     93.3     97.7    100.0    104.6
# 2    수도권    인천광역시   98.000000     84.7     95.6     94.4     95.0     97.1
# 3    수도권      경기도  101.133333     83.4     94.2     97.1     99.3    104.0
# 5   비수도권    부산광역시   94.300000     80.0     88.6     89.0     93.7     95.3
# 6   비수도권    대구광역시   92.316667     77.7     85.7     87.5     91.7     93.3
# 7   비수도권    광주광역시   97.416667     83.4     91.9     92.4     97.9     98.7
# 8   비수도권    대전광역시  101.041667     87.1     94.6     96.3     96.8     97.9
# 9   비수도권    울산광역시  100.483333     83.8     95.8     95.4     99.9    100.9
# 10  비수도권  세종특별자치시  105.691667     83.4    100.5     96.5    107.1    110.8
# 11  비수도권      강원도  106.066667     90.8     95.4    102.3    102.1    105.3
# 12  비수도권     충청북도  104.433333     88.9    100.5     95.5    105.1    106.6
# 13  비수도권     충청남도  101.141667     89.4     95.1     95.3    100.2    106.4
# 14  비수도권     전라북도   98.641667     82.6     90.8     94.7     99.4     95.7
# 15  비수도권     전라남도   99.408333     86.3     90.2     99.6     98.9     92.1
# 16  비수도권     경상북도  100.633333     85.3     94.8     93.8     99.1    101.2
# 17  비수도권     경상남도  101.675000     88.8    100.1    100.9     97.2    103.6
# 18  비수도권  제주특별자치도   96.666667     94.8    101.5     94.2     97.2     96.3
#
#     2023.06  2023.07  2023.08  2023.09  2023.10  2023.11  2023.12
# 1     107.2    111.1    114.8    116.9    110.3    101.6     98.4
# 2     100.1    102.9    104.4    107.7    101.8     96.1     96.2
# 3     103.5    108.7    111.7    112.6    104.7     98.4     96.0
# 5      95.1    101.0    101.2    101.7     98.5     94.6     92.9
# 6      95.9     96.7    104.1    103.0     95.6     88.4     88.2
# 7     102.9    100.4    105.2    106.5    100.0     96.0     93.7
# 8     105.9    108.0    111.7    110.7    106.2     98.4     98.9
# 9     105.9    106.1    107.7    108.4    106.9     97.7     97.3
# 10    115.6    112.9    119.6    122.7    107.1     99.0     93.1
# 11    107.7    112.7    117.3    118.5    109.1    105.1    106.5
# 12    107.3    105.7    110.6    115.3    114.1    104.7     98.9
# 13    102.1    102.8    108.0    107.7    105.3    103.1     98.3
# 14    103.3    103.0    104.1    109.6    103.1     98.0     99.4
# 15     98.3    104.5    107.0    104.8    102.8    105.0    103.4
# 16    106.9    104.4    108.9    111.8    105.4     96.8     99.2
# 17    104.9    106.1    109.0    107.9    105.9     99.7     96.0
# 18     92.3     92.2     98.0    102.3    100.4     91.8     99.0

# %%
house_df_cap=house_df[house_df['지역']=='수도권']

# %%
house_df_oth=house_df[house_df['지역']=='비수도권']

# %%
# 시도별 주택소비심리지수
fig=go.Figure()

fig.add_trace(go.Bar(x=house_df_cap['도시'],
                     y=house_df_cap['평균'],
                     name='수도권',
                     marker_color='rgb(100, 100, 300)',
                     text=round(house_df_cap['평균'])))

fig.add_trace(go.Bar(x=house_df_oth['도시'],
                     y=house_df_oth['평균'],
                     name='비수도권',
                     marker_color='rgb(150,150,450)',
                     text=round(house_df_oth['평균'])))

fig.update_yaxes(range=[50, 150])
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5a3b0ff2-6876-4945-a543-7cdafaed6946" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a3b0ff2-6876-4945-a543-7cdafaed6946")) {                    Plotly.newPlot(                        "5a3b0ff2-6876-4945-a543-7cdafaed6946",                        [{"marker":{"color":"rgb(100, 100, 300)"},"name":"\uc218\ub3c4\uad8c","text":[103.0,98.0,101.0],"x":["\uc11c\uc6b8\ud2b9\ubcc4\uc2dc","\uc778\ucc9c\uad11\uc5ed\uc2dc","\uacbd\uae30\ub3c4"],"y":[103.16666666666667,98.0,101.13333333333334],"type":"bar"},{"marker":{"color":"rgb(150,150,450)"},"name":"\ube44\uc218\ub3c4\uad8c","text":[94.0,92.0,97.0,101.0,100.0,106.0,106.0,104.0,101.0,99.0,99.0,101.0,102.0,97.0],"x":["\ubd80\uc0b0\uad11\uc5ed\uc2dc","\ub300\uad6c\uad11\uc5ed\uc2dc","\uad11\uc8fc\uad11\uc5ed\uc2dc","\ub300\uc804\uad11\uc5ed\uc2dc","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc","\uac15\uc6d0\ub3c4","\ucda9\uccad\ubd81\ub3c4","\ucda9\uccad\ub0a8\ub3c4","\uc804\ub77c\ubd81\ub3c4","\uc804\ub77c\ub0a8\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\uacbd\uc0c1\ub0a8\ub3c4","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4"],"y":[94.30000000000001,92.31666666666668,97.41666666666669,101.04166666666669,100.48333333333333,105.69166666666666,106.06666666666666,104.43333333333334,101.14166666666665,98.6416666666667,99.40833333333335,100.63333333333333,101.675,96.66666666666667],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555 ...

# %% [markdown]
# # 관계

# %%
house_df=house_df.rename(columns={'평균':'주택소비심리지수'})

# %%
house_df=house_df[['지역','도시','주택소비심리지수']]

# %%
house_df.reset_index(inplace=True)
house_df.drop(columns='index', inplace=True)

# %%
house_df
# Out:
#       지역       도시    주택소비심리지수
# 0    수도권    서울특별시  103.166667
# 1    수도권    인천광역시   98.000000
# 2    수도권      경기도  101.133333
# 3   비수도권    부산광역시   94.300000
# 4   비수도권    대구광역시   92.316667
# 5   비수도권    광주광역시   97.416667
# 6   비수도권    대전광역시  101.041667
# 7   비수도권    울산광역시  100.483333
# 8   비수도권  세종특별자치시  105.691667
# 9   비수도권      강원도  106.066667
# 10  비수도권     충청북도  104.433333
# 11  비수도권     충청남도  101.141667
# 12  비수도권     전라북도   98.641667
# 13  비수도권     전라남도   99.408333
# 14  비수도권     경상북도  100.633333
# 15  비수도권     경상남도  101.675000
# 16  비수도권  제주특별자치도   96.666667

# %%
economy_df
# Out:
# 0     지역       도시 1인당 지역총소득 1인당 개인소득
# 0    수도권    서울특별시     57236    26112
# 1   비수도권    부산광역시     32293    22577
# 2   비수도권    대구광역시     31056    22368
# 3    수도권    인천광역시     37442    22406
# 4   비수도권    광주광역시     34844    23669
# 5   비수도권    대전광역시     35848    24220
# 6   비수도권    울산광역시     60971    26066
# 7   비수도권  세종특별자치시     41372    23215
# 8    수도권      경기도     43635    23136
# 9   비수도권      강원도     33198    22395
# 10  비수도권     충청북도     40673    22533
# 11  비수도권     충청남도     48015    22481
# 12  비수도권     전라북도     34299    22262
# 13  비수도권     전라남도     34098    22298
# 14  비수도권     경상북도     38391    21981
# 15  비수도권     경상남도     35540    21887
# 16  비수도권  제주특별자치도     33525    21508

# %%
trafic_df_group.rename(columns={'발생량':'대중교통이용량'}, inplace=True)

# %%
trafic_df_group
# Out:
#       지역       도시     대중교통이용량
# 0   비수도권      강원도    43955463
# 1    수도권      경기도  1833395164
# 2   비수도권     경상남도   165651483
# 3   비수도권     경상북도    91492652
# 4   비수도권    광주광역시   117909907
# 5   비수도권    대구광역시   301327052
# 6   비수도권    대전광역시   167168410
# 7   비수도권    부산광역시   765840871
# 8    수도권    서울특별시  3577353202
# 9   비수도권  세종특별자치시    19927506
# 10  비수도권    울산광역시    80092990
# 11   수도권    인천광역시   479459277
# 12  비수도권     전라남도    61940848
# 13  비수도권     전라북도    62148192
# 14  비수도권  제주특별자치도    53649528
# 15  비수도권     충청남도    99828301
# 16  비수도권     충청북도    59150170

# %%
edu_df_count.drop(columns='합계', inplace=True)

# %%
edu_df_count
# Out:
#       지역       도시  대학  전문대학
# 0   비수도권      강원도  14    13
# 1    수도권      경기도  40    37
# 2   비수도권     경상남도  11    14
# 3   비수도권     경상북도  22    20
# 4   비수도권    광주광역시  11     7
# 5   비수도권    대구광역시   4    10
# 6   비수도권    대전광역시  15     5
# 7   비수도권    부산광역시  17    12
# 8    수도권    서울특별시  57    12
# 9   비수도권  세종특별자치시   3     1
# 10  비수도권    울산광역시   2     3
# 11   수도권    인천광역시   6     6
# 12  비수도권     전라남도  12    11
# 13  비수도권     전라북도  12    11
# 14  비수도권  제주특별자치도   3     4
# 15  비수도권     충청남도  20     9
# 16  비수도권     충청북도  13     6

# %%
geo_df
# Out:
#                                              geometry CTPRVN_CD  \
# 0   POLYGON ((126.98400 37.63600, 126.94800 37.657...        11
# 1   POLYGON ((129.28800 35.32100, 129.26300 35.386...        26
# 2   POLYGON ((128.47300 35.83300, 128.47000 35.806...        27
# 3   MULTIPOLYGON (((126.34300 37.64400, 126.37500 ...        28
# 4   POLYGON ((126.76000 35.25900, 126.73600 35.251...        29
# 5   POLYGON ((127.40200 36.48600, 127.39800 36.490...        30
# 6   POLYGON ((129.34600 35.46500, 129.40800 35.493...        31
# 7   POLYGON ((127.17800 36.59700, 127.19400 36.565...        36
# 8   POLYGON ((127.12700 37.46900, 127.07100 37.432...        41
# 9   POLYGON ((128.54900 38.30200, 128.51300 38.346...        42
# 10  POLYGON ((127.49300 36.23800, 127.53300 36.251...        43
# 11  MULTIPOLYGON (((126.23600 36.86600, 126.20500 ...        44
# 12  POLYGON ((126.62800 35.97800, 126.52300 35.968...        45
# 13  MULTIPOLYGON (((126.59300 34.16200, 126.54000 ...        46
# 14  MULTIPOLYGON (((129.57900 36.05200, 129.54000 ...        47
# 15  MULTIPOLYGON (((128.35100 34.84100, 128.40700 ...        48
# 16  POLYGON ((126.76800 33.56400, 126.73000 33.560...        50
#
#            CTP_ENG_NM CTP_KOR_NM
# 0               Seoul      서울특별시
# 1               Busan      부산광역시
# 2               Daegu      대구광역시
# 3             Incheon      인천광역시
# 4             Gwangju      광주광역시
# 5             Daejeon      대전광역시
# 6               Ulsan      울산광역시
# 7           Sejong-si    세종특별자치시
# 8         Gyeonggi-do        경기도
# 9          Gangwon-do        강원도
# 10  Chungcheongbuk-do       충청북도
# 11  Chungcheongnam-do       충청남도
# 12       Jeollabuk-do       전라북도
# 13        Jellanam-do       전라남도
# 14   Gyeongsangbuk-do       경상북도
# 15   Gyeongsangnam-do       경상남도
# 16            Jeju-do    제주특별자치도

# %%
peo_df=peo_df[['지역','도시','인구수']]

# %%
#peo_df.rename(columns={'계':'인구수'}, inplace=True)

# %%
peo_df
# Out:
#       지역       도시         인구수
# 0    수도권    서울특별시   9334933.5
# 1   비수도권    부산광역시   3291326.0
# 2   비수도권    대구광역시   2372562.0
# 3    수도권    인천광역시   2966979.0
# 4   비수도권    광주광역시   1420562.0
# 5   비수도권    대전광역시   1438846.0
# 6   비수도권    울산광역시   1103825.0
# 7   비수도권  세종특별자치시    384276.5
# 8    수도권      경기도  13545542.5
# 9   비수도권      강원도   1526763.0
# 10  비수도권     충청북도   1589702.0
# 11  비수도권     충청남도   2119950.5
# 12  비수도권     전라북도   1757041.0
# 13  비수도권     전라남도   1806802.0
# 14  비수도권     경상북도   2558213.5
# 15  비수도권     경상남도   3255461.0
# 16  비수도권  제주특별자치도    673099.0

# %%
df_1=df_1[df_1['시점']==2023]

# %%
df_1.rename(columns={'순이동':'인구순이동'}, inplace=True)
# Out:
# <ipython-input-108-74c5afb17cfe>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_1.drop(columns='시점', inplace=True)
# Out:
# <ipython-input-109-771fc3b8acc2>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_1
# Out:
#        지역       도시  인구순이동
# 153   수도권    서울특별시 -31250
# 154  비수도권    부산광역시 -11432
# 155  비수도권    대구광역시  -5288
# 156   수도권    인천광역시  33507
# 157  비수도권    광주광역시  -9017
# 158  비수도권    대전광역시  -2474
# 159  비수도권    울산광역시  -6215
# 160  비수도권  세종특별자치시   1690
# 161   수도권      경기도  44612
# 162  비수도권  강원특별자치도  -1397
# 163  비수도권     충청북도   3873
# 164  비수도권     충청남도  15840
# 165  비수도권     전라북도  -4457
# 166  비수도권     전라남도  -1800
# 167  비수도권     경상북도  -8205
# 168  비수도권     경상남도 -16300
# 169  비수도권  제주특별자치도  -1687

# %%
merge_df = pd.merge(peo_df, trafic_df_group, on=['지역','도시'])

# %%
merge_df = pd.merge(merge_df, edu_df_count, on=['지역','도시'])

# %%
merge_df = pd.merge(merge_df, med_df, on=['지역','도시'])

# %%
merge_df = pd.merge(merge_df, house_df, on=['지역','도시'])

# %%
merge_df = pd.merge(merge_df, economy_df, on=['지역','도시'])

# %%
merge_df
# Out:
#       지역       도시         인구수     대중교통이용량  대학  전문대학 의료기관수    주택소비심리지수  \
# 0    수도권    서울특별시   9334933.5  3577353202  57    12    26  103.166667
# 1   비수도권    부산광역시   3291326.0   765840871  17    12    10   94.300000
# 2   비수도권    대구광역시   2372562.0   301327052   4    10     9   92.316667
# 3    수도권    인천광역시   2966979.0   479459277   6     6     8   98.000000
# 4   비수도권    광주광역시   1420562.0   117909907  11     7    10   97.416667
# 5   비수도권    대전광역시   1438846.0   167168410  15     5     8  101.041667
# 6   비수도권    울산광역시   1103825.0    80092990   2     3     1  100.483333
# 7   비수도권  세종특별자치시    384276.5    19927506   3     1     1  105.691667
# 8    수도권      경기도  13545542.5  1833395164  40    37    32  101.133333
# 9   비수도권      강원도   1526763.0    43955463  14    13    18  106.066667
# 10  비수도권     충청북도   1589702.0    59150170  13     6    12  104.433333
# 11  비수도권     충청남도   2119950.5    99828301  20     9    10  101.141667
# 12  비수도권     전라북도   1757041.0    62148192  12    11    12   98.641667
# 13  비수도권     전라남도   1806802.0    61940848  12    11    22   99.408333
# 14  비수도권     경상북도   2558213.5    91492652  22    20    26  100.633333
# 15  비수도권     경상남도   3255461.0   165651483  11    14    21  101.675000
# 16  비수도권  제주특별자치도    673099.0    53649528   3     4     5   96.666667
#
#    1인당 지역총소득 1인당 개인소득
# 0      57236    26112
# 1      32293    22577
# 2      31056    22368
# 3      37442    22406
# 4      34844    23669
# 5      35848    24220
# 6      60971    26066
# 7      41372    23215
# 8      43635    23136
# 9      33198    22395
# 10     40673    22533
# 11     48015    22481
# 12     34299    22262
# 13     34098    22298
# 14     38391    21981
# 15     35540    21887
# 16     33525    21508

# %%
def convert_to_int(value):
    try:
        return int(value)
    except ValueError:
        return None

convertible_columns = ['1인당 지역총소득', '1인당 개인소득','의료기관수','인구수']
for column in convertible_columns:
    merge_df[column] = merge_df[column].apply(convert_to_int)

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   지역         17 non-null     object
#  1   도시         17 non-null     object
#  2   인구수        17 non-null     int64
#  3   대중교통이용량    17 non-null     int64
#  4   대학         17 non-null     int64
#  5   전문대학       17 non-null     int64
#  6   의료기관수      17 non-null     int64
#  7   주택소비심리지수   17 non-null     float64
#  8   1인당 지역총소득  17 non-null     int64
#  9   1인당 개인소득   17 non-null     int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# ## 상관분석

# %%
corr_matrix = merge_df.corr()
# Out:
# <ipython-input-119-7d3d8a8e49e8>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
corr_matrix
# Out:
#                 인구수   대중교통이용량        대학      전문대학     의료기관수  주택소비심리지수  \
# 인구수        1.000000  0.827751  0.832235  0.805679  0.725838  0.079880
# 대중교통이용량    0.827751  1.000000  0.891809  0.416184  0.533731  0.099552
# 대학         0.832235  0.891809  1.000000  0.604727  0.747302  0.264346
# 전문대학       0.805679  0.416184  0.604727  1.000000  0.847350  0.021264
# 의료기관수      0.725838  0.533731  0.747302  0.847350  1.000000  0.212652
# 주택소비심리지수   0.079880  0.099552  0.264346  0.021264  0.212652  1.000000
# 1인당 지역총소득  0.331336  0.484686  0.423272 -0.025017  0.021255  0.390483
# 1인당 개인소득   0.272140  0.538001  0.395635 -0.151790 -0.075340  0.230152
#
#            1인당 지역총소득  1인당 개인소득
# 인구수         0.331336  0.272140
# 대중교통이용량     0.484686  0.538001
# 대학          0.423272  0.395635
# 전문대학       -0.025017 -0.151790
# 의료기관수       0.021255 -0.075340
# 주택소비심리지수    0.390483  0.230152
# 1인당 지역총소득   1.000000  0.791304
# 1인당 개인소득    0.791304  1.000000

# %%
trace = go.Heatmap(z=corr_matrix.values,
                   x=corr_matrix.columns,
                   y=corr_matrix.index,
                   colorscale='blues')

fig = go.Figure(data=[trace])

annotations = []
for i, row in enumerate(corr_matrix.values):
    for j, value in enumerate(row):
        annotations.append(
            dict(
                x=corr_matrix.columns[j],
                y=corr_matrix.index[i],
                text=str(round(value, 2)),
                showarrow=False
            )
        )


fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
    annotations=annotations
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df154e6b-81c5-4796-b8bb-500132babbca" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df154e6b-81c5-4796-b8bb-500132babbca")) {                    Plotly.newPlot(                        "df154e6b-81c5-4796-b8bb-500132babbca",                        [{"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":["\uc778\uad6c\uc218","\ub300\uc911\uad50\ud1b5\uc774\uc6a9\ub7c9","\ub300\ud559","\uc804\ubb38\ub300\ud559","\uc758\ub8cc\uae30\uad00\uc218","\uc8fc\ud0dd\uc18c\ube44\uc2ec\ub9ac\uc9c0\uc218","1\uc778\ub2f9 \uc9c0\uc5ed\ucd1d\uc18c\ub4dd","1\uc778\ub2f9 \uac1c\uc778\uc18c\ub4dd"],"y":["\uc778\uad6c\uc218","\ub300\uc911\uad50\ud1b5\uc774\uc6a9\ub7c9","\ub300\ud559","\uc804\ubb38\ub300\ud559","\uc758\ub8cc\uae30\uad00\uc218","\uc8fc\ud0dd\uc18c\ube44\uc2ec\ub9ac\uc9c0\uc218","1\uc778\ub2f9 \uc9c0\uc5ed\ucd1d\uc18c\ub4dd","1\uc778\ub2f9 \uac1c\uc778\uc18c\ub4dd"],"z":[[1.0,0.8277507671971314,0.8322346961862178,0.8056789340974884,0.7258380497819393,0.07987952794052341,0.33133559093156584,0.27214023418681493],[0.8277507671971314,1.0,0.8918089774599229,0.4161842672153368,0.5337307499964973,0.09955249677737986,0.4846855701893967,0.5380014933017795],[0.8322346961862178,0.8918089774599229,1.0,0.6047269935404805,0.7473021045103645,0.26434571919923966,0.423271685384429,0.395635061115647],[0.8056789340974884,0.4161842672153368,0.6047269935404805,1.0,0.84734971703669,0.021263630225439874,-0.025017478442583223,-0.15179018519565307],[0.7258380497819393,0.5337307499964973,0.7473021045103645,0.84734971703669,1.0,0.21265246261848997,0.0212550331655609,-0.07533990780137267],[0.07987952794052341,0.09955249677737986,0.26434571919923966,0.021263630225439874,0.21265246261848997,1.0,0.39048330403274717,0.23015163174306358],[0.33133559093156584,0.4846855701893967,0.423271685384429,-0.025017478442583223,0.0212550331655609,0.39048330403274717,1.0,0.7913038626908627],[0.27214023418681493,0.5380014933017795,0.395635061115647,-0.15179018519565307,-0.07533990780137267,0.23015163174306358,0.7913038626908627,1.0]],"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444 ...

# %%
corr_matrix['인구수']
# Out:
# 인구수          1.000000
# 대중교통이용량      0.827751
# 대학           0.832235
# 전문대학         0.805679
# 의료기관수        0.725838
# 주택소비심리지수     0.079880
# 1인당 지역총소득    0.331336
# 1인당 개인소득     0.272140
# Name: 인구수, dtype: float64

# %% [markdown]
# ## 회귀분석

# %%
X = merge_df[['주택소비심리지수',	'1인당 지역총소득',	'1인당 개인소득',	'대중교통이용량',	'대학',	'전문대학','의료기관수']]
y = merge_df['인구수']

X = sm.add_constant(X)

StatsModels_model = sm.OLS(y, X).fit()

print(StatsModels_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    인구수   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     38.97
# Date:                Thu, 14 Mar 2024   Prob (F-statistic):           5.04e-06
# Time:                        08:01:32   Log-Likelihood:                -249.81
# No. Observations:                  17   AIC:                             515.6
# Df Residuals:                       9   BIC:                             522.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.134e+06   8.62e+06     -0.712      0.495   -2.56e+07    1.34e+07
# 주택소비심리지수    6.762e+04   6.96e+04      0.971      0.357   -8.99e+04    2.25e+05
# 1인당 지역총소득     21.5187     42.164      0.510      0.622     -73.864     116.901
# 1인당 개인소득     -58.5335    287.423     -0.204      0.843    -708.729     591.662
# 대중교통이용량        0.0029      0.001      4.758      0.001       0.002       0.004
# 대학          -5.31e+04   4.87e+04     -1.090      0.304   -1.63e+05    5.71e+04
# 전문대학        3.251e+05   4.94e+04      6.575      0.000    2.13e+05    4.37e+05
# 의료기관수      -8.413e+04   5.78e+04     -1.456      0.179   -2.15e+05    4.66e+04
# ==============================================================================
# Omnibus:                        2.019   Durbin-Watson:                   2.661
# Prob(Omnibus):                  0.364   Jarque-Bera (JB):                1.193
# Skew:                          -0.338   Prob(JB):                        0.551
# Kurtosis:                       1.893   Cond. No.                     4.46e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:1806: UserWarning:
#
# kurtosistest only valid for n>=20 ... continuing anyway, n=17

# %%
predicted_values = StatsModels_model.predict(X)

results_df = pd.DataFrame({'Actual': y, 'Predict': predicted_values})

fig = px.scatter(results_df, x='Actual', y='Predict')

fig.add_scatter(x=results_df['Actual'], y=results_df['Actual'], mode='lines', name='회귀선')

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aa7a4eef-5b1e-456f-9aae-f95a8edbaaac" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa7a4eef-5b1e-456f-9aae-f95a8edbaaac")) {                    Plotly.newPlot(                        "aa7a4eef-5b1e-456f-9aae-f95a8edbaaac",                        [{"hovertemplate":"Actual=%{x}\u003cbr\u003ePredict=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[9334933,3291326,2372562,2966979,1420562,1438846,1103825,384276,13545542,1526763,1589702,2119950,1757041,1806802,2558213,3255461,673099],"xaxis":"x","y":[9645502.211060528,4003286.375129086,2627005.2219745563,2342413.490314869,1012230.4610204024,695695.7202892099,1466004.7815218868,684893.2092290372,12839799.326722704,2539515.1157798385,908060.6521973237,1736816.072911385,2082544.9881775258,1286088.4753319998,3624476.215953253,2908896.8209919175,742652.8903143257],"yaxis":"y","type":"scatter"},{"mode":"lines","name":"\ud68c\uadc0\uc120","x":[9334933,3291326,2372562,2966979,1420562,1438846,1103825,384276,13545542,1526763,1589702,2119950,1757041,1806802,2558213,3255461,673099],"y":[9334933,3291326,2372562,2966979,1420562,1438846,1103825,384276,13545542,1526763,1589702,2119950,1757041,1806802,2558213,3255461,673099],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"], ...

# %% [markdown]
# # 지역편차

# %%
rat_df = merge_df.iloc[:, 2:].apply(lambda x: x / x.sum() * 100)

# %%
rat_df = round(rat_df * (corr_matrix['인구수']),2)

# %%
rat_df = pd.concat([merge_df.iloc[:, :2], rat_df], axis=1)

# %%
rat_df.sum(axis=1)
# Out:
# <ipython-input-128-460515e10f31>:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 0     92.10
# 1     31.86
# 2     19.84
# 3     21.72
# 4     17.58
# 5     17.97
# 6     10.56
# 7      6.83
# 8     88.96
# 9     23.05
# 10    18.35
# 11    23.08
# 12    20.26
# 13    23.49
# 14    33.90
# 15    28.16
# 16     9.78
# dtype: float64

# %%
rat_df['지역편차'] = round(rat_df.sum(axis=1), 2)
# Out:
# <ipython-input-129-20699196306e>:1: FutureWarning:
#
# Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
rat_df
# Out:
#       지역       도시    인구수  대중교통이용량     대학   전문대학  의료기관수  주택소비심리지수  1인당 지역총소득  \
# 0    수도권    서울특별시  18.25    37.11  18.11   5.34   8.17      0.48       2.82
# 1   비수도권    부산광역시   6.44     7.94   5.40   5.34   3.14      0.44       1.59
# 2   비수도권    대구광역시   4.64     3.13   1.27   4.45   2.83      0.43       1.53
# 3    수도권    인천광역시   5.80     4.97   1.91   2.67   2.51      0.46       1.84
# 4   비수도권    광주광역시   2.78     1.22   3.49   3.12   3.14      0.46       1.72
# 5   비수도권    대전광역시   2.81     1.73   4.76   2.23   2.51      0.47       1.77
# 6   비수도권    울산광역시   2.16     0.83   0.64   1.34   0.31      0.47       3.00
# 7   비수도권  세종특별자치시   0.75     0.21   0.95   0.45   0.31      0.50       2.04
# 8    수도권      경기도  26.48    19.02  12.71  16.47  10.05      0.47       2.15
# 9   비수도권      강원도   2.99     0.46   4.45   5.79   5.66      0.50       1.64
# 10  비수도권     충청북도   3.11     0.61   4.13   2.67   3.77      0.49       2.00
# 11  비수도권     충청남도   4.14     1.04   6.35   4.01   3.14      0.47       2.37
# 12  비수도권     전라북도   3.44     0.64   3.81   4.90   3.77      0.46       1.69
# 13  비수도권     전라남도   3.53     0.64   3.81   4.90   6.91      0.47       1.68
# 14  비수도권     경상북도   5.00     0.95   6.99   8.90   8.17      0.47       1.89
# 15  비수도권     경상남도   6.37     1.72   3.49   6.23   6.60      0.48       1.75
# 16  비수도권  제주특별자치도   1.32     0.56   0.95   1.78   1.57      0.45       1.65
#
#     1인당 개인소득   지역편차
# 0       1.82  92.10
# 1       1.57  31.86
# 2       1.56  19.84
# 3       1.56  21.72
# 4       1.65  17.58
# 5       1.69  17.97
# 6       1.81  10.56
# 7       1.62   6.83
# 8       1.61  88.96
# 9       1.56  23.05
# 10      1.57  18.35
# 11      1.56  23.08
# 12      1.55  20.26
# 13      1.55  23.49
# 14      1.53  33.90
# 15      1.52  28.16
# 16      1.50   9.78

# %%
rat_df=rat_df.sort_values('지역편차', ascending=False)

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=rat_df['도시'],
                     y=rat_df['지역편차'],
                     marker_color='rgb(100,100,300)',
                     name='지역편차',
                     text=round(rat_df['지역편차'])))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="122330d8-d4ff-45d7-b44d-76be20a7ee51" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("122330d8-d4ff-45d7-b44d-76be20a7ee51")) {                    Plotly.newPlot(                        "122330d8-d4ff-45d7-b44d-76be20a7ee51",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uc9c0\uc5ed\ud3b8\ucc28","text":[92.0,89.0,34.0,32.0,28.0,23.0,23.0,23.0,22.0,20.0,20.0,18.0,18.0,18.0,11.0,10.0,7.0],"x":["\uc11c\uc6b8\ud2b9\ubcc4\uc2dc","\uacbd\uae30\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\ubd80\uc0b0\uad11\uc5ed\uc2dc","\uacbd\uc0c1\ub0a8\ub3c4","\uc804\ub77c\ub0a8\ub3c4","\ucda9\uccad\ub0a8\ub3c4","\uac15\uc6d0\ub3c4","\uc778\ucc9c\uad11\uc5ed\uc2dc","\uc804\ub77c\ubd81\ub3c4","\ub300\uad6c\uad11\uc5ed\uc2dc","\ucda9\uccad\ubd81\ub3c4","\ub300\uc804\uad11\uc5ed\uc2dc","\uad11\uc8fc\uad11\uc5ed\uc2dc","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc"],"y":[92.1,88.96,33.9,31.86,28.16,23.49,23.08,23.05,21.72,20.26,19.84,18.35,17.97,17.58,10.56,9.78,6.83],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[ ...

# %% [markdown]
# # 지역선정

# %%
select_df = merge_df[(merge_df['지역'] == '비수도권')]

# %%
selec_df=select_df[['도시','대중교통이용량','전문대학','인구수']]

# %%
selec_df_rat = selec_df.iloc[:, 1:].apply(lambda x: x / x.sum() * 100)

# %%
selec_df_rat.iloc[:, 0] = selec_df_rat.iloc[:, 0] * 0.83
selec_df_rat.iloc[:, 2] = selec_df_rat.iloc[:, 2] * 0.81

# %%
selec_df_rat['점수'] = selec_df_rat.sum(axis=1)

# %%
selec_df_rat = pd.concat([merge_df.iloc[:, :2], selec_df_rat], axis=1)

# %%
selec_df_rat.dropna(inplace=True)

# %%
selec_df_rat.sort_values('점수', ascending=False, inplace=True)

# %%
selec_df_rat
# Out:
#       지역       도시    대중교통이용량       전문대학        인구수         점수
# 1   비수도권    부산광역시  30.412563   9.523810  10.538102  50.474474
# 15  비수도권     경상남도   6.578241  11.111111  10.423270  28.112622
# 14  비수도권     경상북도   3.633295  15.873016   8.190835  27.697146
# 2   비수도권    대구광역시  11.966099   7.936508   7.596421  27.499029
# 11  비수도권     충청남도   3.964315   7.142857   6.787613  17.894786
# 13  비수도권     전라남도   2.459754   8.730159   5.784982  16.974895
# 9   비수도권      강원도   1.745530  10.317460   4.888359  16.951350
# 12  비수도권     전라북도   2.467988   8.730159   5.625659  16.823805
# 5   비수도권    대전광역시   6.638481   3.968254   4.606868  15.213603
# 4   비수도권    광주광역시   4.682360   5.555556   4.548327  14.786242
# 10  비수도권     충청북도   2.348932   4.761905   5.089876  12.200713
# 6   비수도권    울산광역시   3.180600   2.380952   3.534205   9.095757
# 16  비수도권  제주특별자치도   2.130494   3.174603   2.155115   7.460212
# 7   비수도권  세종특별자치시   0.791348   0.793651   1.230367   2.815366

# %%
fig = go.Figure()

fig.add_trace(go.Bar(x=selec_df_rat['도시'],
                     y=selec_df_rat['점수'],
                     marker_color='rgb(100,100,300)',
                     name='점수',
                     text=round(selec_df_rat['점수'])))

fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=50,
        t=50,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7d127ec9-32fc-4c6d-a9cc-d00286f9bd22" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d127ec9-32fc-4c6d-a9cc-d00286f9bd22")) {                    Plotly.newPlot(                        "7d127ec9-32fc-4c6d-a9cc-d00286f9bd22",                        [{"marker":{"color":"rgb(100,100,300)"},"name":"\uc810\uc218","text":[50.0,28.0,28.0,27.0,18.0,17.0,17.0,17.0,15.0,15.0,12.0,9.0,7.0,3.0],"x":["\ubd80\uc0b0\uad11\uc5ed\uc2dc","\uacbd\uc0c1\ub0a8\ub3c4","\uacbd\uc0c1\ubd81\ub3c4","\ub300\uad6c\uad11\uc5ed\uc2dc","\ucda9\uccad\ub0a8\ub3c4","\uc804\ub77c\ub0a8\ub3c4","\uac15\uc6d0\ub3c4","\uc804\ub77c\ubd81\ub3c4","\ub300\uc804\uad11\uc5ed\uc2dc","\uad11\uc8fc\uad11\uc5ed\uc2dc","\ucda9\uccad\ubd81\ub3c4","\uc6b8\uc0b0\uad11\uc5ed\uc2dc","\uc81c\uc8fc\ud2b9\ubcc4\uc790\uce58\ub3c4","\uc138\uc885\ud2b9\ubcc4\uc790\uce58\uc2dc"],"y":[50.47447419717852,28.112622383664043,27.697146320771306,27.49902878358186,17.894785642244162,16.974894915835335,16.951349602385918,16.823805049777246,15.21360291922446,14.786242270995617,12.200712968866657,9.09575667306749,7.460212422739988,2.8153658496673977],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"s ...
